# %% [markdown]
# # Project Title: Analysis of Global Wealth Distribution
#
# ---
#
# ## Introduction
#
# This project aims to analyze a dataset containing information on the net worth of various individuals worldwide. The analysis focuses on identifying patterns and insights related to industry distribution, geographical distribution, age, gender, and other relevant factors.
#
# ---
#
# ## Dataset Overview
#
# - **Dataset Description**: The dataset includes attributes such as ranking, final worth, industry category, person name, age, country, city, source of wealth, and other socio-economic indicators.
# - **Key Columns**:
#   - `ranking`
#   - `finalWorth`
#   - `category`
#   - `personName`
#   - `age`
#   - `country`
#   - `city`
#   - `source`
#   - `industries`
#   - `countryOfCitizenship`
#   - `selfMade`
#   - `status`
#   - `gender`
#   - `birthDate`
#   - `lastName`
#   - `firstName`
#   - `date_1`
#   - `birthYear`
#   - `birthMonth`
#   - `birthDay`
#   - `cpi_country`
#   - `gdp_country`
#   - `gross_tertiary_education_enrollment`
#   - `gross_primary_education_enrollment_country`
#   - `life_expectancy_country`
#   - `tax_revenue_country_country`
#   - `total_tax_rate_country`
#   - `population_country`
#   - `latitude_country`
#   - `longitude_country`
#
# ---
#
# ## Analysis Goals
#
# 1. **Industry Analysis**: Determine the distribution of net worth across different industries.
# 2. **Geographical Analysis**: Explore the geographical distribution of net worth across countries and cities.
# 3. **Demographic Analysis**: Analyze net worth by age, gender, and self-made status.
# 4. **Correlation Analysis**: Investigate relationships between net worth and various socio-economic indicators.
#
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv("Billionaires_Statistics_Dataset.csv")

# %%
df.head()
# Out:
#    ranking  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 35 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   ranking                                     2640 non-null   int64
#  1   finalWorth                                  2640 non-null   int64
#  2   category                                    2640 non-null   object
#  3   personName                                  2640 non-null   object
#  4   age                                         2575 non-null   float64
#  5   country                                     2602 non-null   object
#  6   city                                        2568 non-null   object
#  7   source                                      2640 non-null   object
#  8   industries                                  2640 non-null   object
#  9   countryOfCitizenship                        2640 non-null   object
# ...

# %%
df.describe()
# Out:
#            ranking     finalWorth          age    birthYear   birthMonth  \
# count  2640.000000    2640.000000  2575.000000  2564.000000  2564.000000
# mean   1289.159091    4623.787879    65.140194  1957.183307     5.740250
# std     739.693726    9834.240939    13.258098    13.282516     3.710085
# min       1.000000    1000.000000    18.000000  1921.000000     1.000000
# 25%     659.000000    1500.000000    56.000000  1948.000000     2.000000
# 50%    1312.000000    2300.000000    65.000000  1957.000000     6.000000
# 75%    1905.000000    4200.000000    75.000000  1966.000000     9.000000
# max    2540.000000  211000.000000   101.000000  2004.000000    12.000000
#
#           birthDay  cpi_country  cpi_change_country  \
# count  2564.000000  2456.000000         2456.000000
# mean     12.099844   127.755204            4.364169
# std       9.918876    26.452951            3.623763
# min       1.000000    99.550000           -1.900000
# ...

# %%
print(df.isnull().sum())
# Out:
# ranking                                          0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                             65
# country                                         38
# city                                            72
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# birthDate                                       76
# lastName                                         0
# firstName                                        3
# title                                         2301
# ...

# %%
# Dropping columns with a high proportion of missing values
columns_to_drop = ['organization', 'title', 'state', 'residenceStateRegion']
df_cleaned = df.drop(columns=columns_to_drop)

# %%
# Imputing missing values for numerical columns
df_cleaned['age'].fillna(df_cleaned['age'].median(), inplace=True)
df_cleaned['birthYear'].fillna(df_cleaned['birthYear'].mode()[0], inplace=True)
df_cleaned['birthMonth'].fillna(df_cleaned['birthMonth'].mode()[0], inplace=True)
df_cleaned['birthDay'].fillna(df_cleaned['birthDay'].mode()[0], inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16024\1019685657.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned['age'].fillna(df_cleaned['age'].median(), inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_16024\1019685657.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Imputing missing values for categorical columns
df_cleaned['country'].fillna('Unknown', inplace=True)
df_cleaned['city'].fillna('Unknown', inplace=True)
df_cleaned['firstName'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16024\2799444749.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned['country'].fillna('Unknown', inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_16024\2799444749.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# 1. Distribution of Net Worth by Country:

# %%
import seaborn as sns

# Boxplot of Net Worth by Country
plt.figure(figsize=(12, 8))
sns.boxplot(x='country', y='finalWorth', data=df_cleaned)
plt.xticks(rotation=90)
plt.title('Net Worth Distribution by Country')
plt.show()

# %% [markdown]
# 2. Age vs. Net Worth:

# %%
# Scatter plot of Age vs. Net Worth
plt.figure(figsize=(10, 6))
plt.scatter(df_cleaned['age'], df_cleaned['finalWorth'])
plt.xlabel('Age')
plt.ylabel('Net Worth')
plt.title('Age vs. Net Worth')
plt.show()

# %% [markdown]
# 3. Top Industries by Average Net Worth

# %%
# Average Net Worth by Industry
industry_net_worth = df_cleaned.groupby('industries')['finalWorth'].mean().sort_values(ascending=False)
print(industry_net_worth.head(10))
# Out:
# industries
# Automotive               7195.890411
# Telecom                  6564.516129
# Fashion & Retail         6386.466165
# Metals & Mining          6037.837838
# Logistics                5987.500000
# Technology               5980.573248
# Diversified              4840.641711
# Gambling & Casinos       4820.000000
# Media & Entertainment    4697.802198
# Energy                   4535.000000
# Name: finalWorth, dtype: float64

# %% [markdown]
# 4. Correlation Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_df = df_cleaned.select_dtypes(include='number')

# Handle missing values by filling them with the median
numeric_df = numeric_df.fillna(numeric_df.median())

# Compute the correlation matrix
corr = numeric_df.corr()

# Generate a heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# 5. Net Worth Distribution by Category

# %%
# Violin plot of Net Worth by Category
plt.figure(figsize=(12, 8))
sns.violinplot(x='category', y='finalWorth', data=df_cleaned, inner='quartile')
plt.xticks(rotation=90)
plt.title('Net Worth Distribution by Category')
plt.show()

# %% [markdown]
# 6. Interactive Geographical Plot

# %%
import plotly.io as pio
import plotly.express as px

# Create a DataFrame with necessary columns
geo_df = df_cleaned[['personName', 'finalWorth', 'country', 'latitude_country', 'longitude_country']].dropna()

# Create the plot
fig = px.scatter_geo(geo_df,
                     lat='latitude_country',
                     lon='longitude_country',
                     hover_name='personName',
                     size='finalWorth',
                     color='country',
                     title='Global Distribution of Net Worth')

# Save the plot to an HTML file
pio.write_html(fig, 'net_worth_distribution.html')

# %%
print(geo_df.head())
print(geo_df.shape)
# Out:
#                  personName  finalWorth        country  latitude_country  \
# 0  Bernard Arnault & family      211000         France         46.227638
# 1                 Elon Musk      180000  United States         37.090240
# 2                Jeff Bezos      114000  United States         37.090240
# 3             Larry Ellison      107000  United States         37.090240
# 4            Warren Buffett      106000  United States         37.090240
#
#    longitude_country
# 0           2.213749
# 1         -95.712891
# 2         -95.712891
# 3         -95.712891
# 4         -95.712891
# (2476, 5)

# %%
import plotly.express as px
import pandas as pd

# Example DataFrame
data = {
    'personName': ['Person A', 'Person B'],
    'finalWorth': [1000000, 2000000],
    'country': ['Country A', 'Country B'],
    'latitude_country': [10.0, 20.0],
    'longitude_country': [10.0, 20.0]
}

df = pd.DataFrame(data)

# Create the plot
fig = px.scatter_geo(df,
                     lat='latitude_country',
                     lon='longitude_country',
                     hover_name='personName',
                     size='finalWorth',
                     color='country',
                     title='Global Distribution of Net Worth')

# Display the plot
import plotly.io as pio
pio.show(fig)

# %%
import plotly.express as px

# Example: Bar plot
fig = px.bar(df, x='personName', y='finalWorth', color='country', title='Net Worth by Person')
pio.show(fig)

# %% [markdown]
# 7. Net Worth vs. GDP of Countries

# %%
# Scatter plot of Net Worth vs. GDP
plt.figure(figsize=(12, 8))
sns.scatterplot(x='gdp_country', y='finalWorth', hue='country', data=df_cleaned, palette='viridis', s=100, alpha=0.6)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('GDP of Country')
plt.ylabel('Net Worth')
plt.title('Net Worth vs. GDP of Countries')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# 8. Top 10 Richest Individuals by Country

# %%
# Top 10 Richest Individuals by Country
top_richest_by_country = df_cleaned.groupby('country').apply(lambda x: x.nlargest(10, 'finalWorth')).reset_index(drop=True)
print(top_richest_by_country[['country', 'personName', 'finalWorth']])
# Out:
#        country                       personName  finalWorth
# 0      Algeria            Issad Rebrab & family        4600
# 1      Andorra                   Carmen Thyssen        1500
# 2    Argentina                  Marcos Galperin        4900
# 3    Argentina  Gregorio Perez Companc & family        2900
# 4    Argentina                Eduardo Eurnekian        1900
# ..         ...                              ...         ...
# 441    Vietnam           Thi Phuong Thao Nguyen        2200
# 442    Vietnam                   Tran Dinh Long        1800
# 443    Vietnam                      Ho Hung Anh        1500
# 444    Vietnam           Tran Ba Duong & family        1500
# 445    Vietnam                Nguyen Dang Quang        1300
#
# [446 rows x 3 columns]
# C:\Users\HP\AppData\Local\Temp\ipykernel_16024\3726086155.py:2: DeprecationWarning:
#
# ...

# %% [markdown]
# 9. Age Distribution of Top 100 Richest Individuals

# %%
# Age Distribution of Top 100 Richest Individuals
top_100 = df_cleaned.nlargest(100, 'finalWorth')
plt.figure(figsize=(10, 6))
sns.histplot(top_100['age'], bins=20, kde=True)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Top 100 Richest Individuals')
plt.show()

# %% [markdown]
# 10. Net Worth vs. Education Enrollment Rates

# %%
# Scatter plot of Net Worth vs. Tertiary Education Enrollment Rates
plt.figure(figsize=(10, 6))
sns.scatterplot(x='gross_tertiary_education_enrollment', y='finalWorth', hue='country', data=df_cleaned, palette='cubehelix', s=100, alpha=0.6)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Gross Tertiary Education Enrollment Rate')
plt.ylabel('Net Worth')
plt.title('Net Worth vs. Tertiary Education Enrollment Rates')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# 11. Distribution of Net Worth by Industry

# %%
import plotly.express as px

# Aggregate net worth by industry
industry_net_worth = df_cleaned.groupby('category')['finalWorth'].sum().reset_index()

# Create a bar plot
fig = px.bar(industry_net_worth, x='category', y='finalWorth',
             title='Total Net Worth by Industry',
             labels={'category': 'Industry', 'finalWorth': 'Total Net Worth'})
fig.show()

# %% [markdown]
# 12. Net Worth Distribution by Country

# %%
# Aggregate net worth by country
country_net_worth = df_cleaned.groupby('country')['finalWorth'].sum().reset_index()

# Create a bar plot
fig = px.bar(country_net_worth, x='country', y='finalWorth',
             title='Total Net Worth by Country',
             labels={'country': 'Country', 'finalWorth': 'Total Net Worth'})
fig.show()

# %% [markdown]
# 13. Correlation Between Age and Net Worth

# %%
import plotly.express as px

# Scatter plot of age vs. net worth
fig = px.scatter(df_cleaned, x='age', y='finalWorth',
                 title='Age vs. Net Worth',
                 labels={'age': 'Age', 'finalWorth': 'Net Worth'})
fig.show()

# Calculate correlation
correlation = df_cleaned[['age', 'finalWorth']].corr().iloc[0, 1]
print(f'Correlation between age and net worth: {correlation}')
# Out:
# Correlation between age and net worth: 0.06700939891615988

# %% [markdown]
# 14. Net Worth Distribution by Gender

# %%
# Aggregate net worth by gender
gender_net_worth = df_cleaned.groupby('gender')['finalWorth'].sum().reset_index()

# Create a bar plot
fig = px.bar(gender_net_worth, x='gender', y='finalWorth',
             title='Total Net Worth by Gender',
             labels={'gender': 'Gender', 'finalWorth': 'Total Net Worth'})
fig.show()

# %% [markdown]
# 15. Net Worth by Self-Made Status

# %%
# Aggregate net worth by self-made status
self_made_net_worth = df_cleaned.groupby('selfMade')['finalWorth'].sum().reset_index()

# Create a bar plot
fig = px.bar(self_made_net_worth, x='selfMade', y='finalWorth',
             title='Total Net Worth by Wealth Source',
             labels={'selfMade': 'Wealth Source', 'finalWorth': 'Total Net Worth'})
fig.show()

# %% [markdown]
# Conclusion:
#
# The analysis revealed that net worth is highest in industries like Technology and Finance & Investments. The United States, particularly cities like Austin and Omaha, dominates in wealth concentration. Age and self-made status also significantly influence net worth, with older and self-made individuals often having higher net worths.
